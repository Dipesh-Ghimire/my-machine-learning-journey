# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
df = pd.read_csv("canada_per_capita_income.csv");

# %%
# %matplotlib inline
plt.xlabel("year")
plt.ylabel("PCI(US$)")
plt.scatter(df.year,df.PCI,color='red',marker='+')

# %%
regobj = linear_model.LinearRegression()

# %%
regobj.fit(df[['year']],df.PCI)
# Out:
# LinearRegression()

# %%
regobj.predict([[1990]])
# Out:
# /home/dipesh/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([16434.74183774])

# %%
# %matplotlib inline
plt.xlabel("year")
plt.ylabel("PCI(US$)")
plt.scatter(df.year,df.PCI,color='red',marker='+')
plt.plot(df.year,regobj.predict(df[['year']]),color='blue')

# %%
df.head(4)
# Out:
#    year          PCI
# 0  1970  3399.299037
# 1  1971  3768.297935
# 2  1972  4251.175484
# 3  1973  4804.463248
